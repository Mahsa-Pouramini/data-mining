# %%
import numpy as np
import pandas as pd

from pathlib import Path

# %%
df = pd.read_csv( "train.csv", index_col="Id")

# %%
df.columns

# %% [markdown]
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street', 'Alley',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
#        'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond',
#        'PavedDrive', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
#        'ScreenPorch', 'PoolArea', 'PoolQC', 'Fence', 'MiscFeature', 'MiscVal',
#        'MoSold', 'YrSold', 'SaleType', 'SaleCondition', 'SalePrice'],
#       dtype='object')

# %%
for column in df.columns:
    print("1) ویژگی ها", '\n')
    print("برچسب هایش:", '\n')
    print('\n')
    print("نوع:", '\n')
    print('\n')
    print("2)  گسسته یا پیوسته؟", '\n')
    print('\n')
    print("3) دامنه", '\n')
    
    print(df[column].describe())
    print("----------------------------------------------------------------------------")

# %%
1) ویژگی ها 
MSSubClass: .نوع مسکن درگیر در فروش را مشخص می کند
    
برچسب هایش: 
        20	1-STORY 1946 & NEWER ALL STYLES
        30	1-STORY 1945 & OLDER
        40	1-STORY W/FINISHED ATTIC ALL AGES
        45	1-1/2 STORY - UNFINISHED ALL AGES
        50	1-1/2 STORY FINISHED ALL AGES
        60	2-STORY 1946 & NEWER
        70	2-STORY 1945 & OLDER
        75	2-1/2 STORY ALL AGES
        80	SPLIT OR MULTI-LEVEL
        85	SPLIT FOYER
        90	DUPLEX - ALL STYLES AND AGES
       120	1-STORY PUD (Planned Unit Development) - 1946 & NEWER
       150	1-1/2 STORY PUD - ALL AGES
       160	2-STORY PUD - 1946 & NEWER
       180	PUD - MULTILEVEL - INCL SPLIT LEV/FOYER
       190	2 FAMILY CONVERSION - ALL STYLES AND AGES

نوع: 

    Numeric

2)  گسسته یا پیوسته؟ 

    گسسته

3) دامنه 

count    1460.000000
mean       56.897260
std        42.300571

min        20.000000
max       190.000000

Name: MSSubClass, dtype: float64
----------------------------------------------------------------------------
1) ویژگی ها 
MSZoning: .طبقه بندی کلی منطقه بندی فروش را مشخص می کند
    
برچسب هایش: 

       A	Agriculture
       C	Commercial
       FV	Floating Village Residential
       I	Industrial
       RH	Residential High Density
       RL	Residential Low Density
       RP	Residential Low Density Park 
       RM	Residential Medium Density

نوع: 

    Nominal

2)  گسسته یا پیوسته؟ 

    گسسته

3) دامنه 

count     1460
unique       5
top         RL
freq      1151
Name: MSZoning, dtype: object
----------------------------------------------------------------------------
1) ویژگی ها 
LotFrontage:  مساحت خیابان متصل به ملک  
    
برچسب هایش: 

 ------

نوع: 

    Numeric

2)  گسسته یا پیوسته؟ 

   پیوسته 

3) دامنه 

count    1201.000000
mean       70.049958
std        24.284752

min        21.000000
max       313.000000

Name: LotFrontage, dtype: float64
----------------------------------------------------------------------------
1) ویژگی ها 
LotArea: مساحت قطعه در متر مربع
    
برچسب هایش: 

  ------

نوع: 

    Numeric

2)  گسسته یا پیوسته؟ 

    پیوسته

3) دامنه 

count      1460.000000
mean      10516.828082
std        9981.264932

min        1300.000000
max      215245.000000

Name: LotArea, dtype: float64
----------------------------------------------------------------------------
1) ویژگی ها 
Street: نوع جاده دسترسی به ملک
    
برچسب هایش: 

       Grvl	Gravel	
       Pave	Paved

نوع: 

    Binary

2)  گسسته یا پیوسته؟ 

    گسسته

3) دامنه 

count     1460
unique       2
top       Pave
freq      1454
Name: Street, dtype: object
----------------------------------------------------------------------------
1) ویژگی ها 
Alley: نوع دسترسی کوچه به ملک
    
برچسب هایش: 

       Grvl	Gravel
       Pave	Paved
       NA 	No alley access

نوع: 

    Nominal

2)  گسسته یا پیوسته؟ 

    گسسته

3) دامنه 

count       91
unique       2
top       Grvl
freq        50
Name: Alley, dtype: object
----------------------------------------------------------------------------
1) ویژگی ها 
LotShape: شکل کلی ملک
    
برچسب هایش: 

       Reg	Regular	
       IR1	Slightly irregular
       IR2	Moderately Irregular
       IR3	Irregular

نوع: 

    Nominal

2)  گسسته یا پیوسته؟ 

    گسسته

3) دامنه 

count     1460
unique       4
top        Reg
freq       925
Name: LotShape, dtype: object
----------------------------------------------------------------------------
1) ویژگی ها 
LandContour: مسطح بودن ملک
    
برچسب هایش: 

       Lvl	Near Flat/Level	
       Bnk	Banked - Quick and significant rise from street grade to building
       HLS	Hillside - Significant slope from side to side
       Low	Depression

نوع: 

    Nominal

2)  گسسته یا پیوسته؟ 

    گسسته 

3) دامنه 

count     1460
unique       4
top        Lvl
freq      1311
Name: LandContour, dtype: object
----------------------------------------------------------------------------
1) ویژگی ها 
Utilities: نوع تاسیسات موجود
    
برچسب هایش: 

       AllPub	All public Utilities (E,G,W,& S)	
       NoSewr	Electricity, Gas, and Water (Septic Tank)
       NoSeWa	Electricity and Gas Only
       ELO	Electricity only

نوع: 

    Nominal

2)  گسسته یا پیوسته؟ 

    گسسته

3) دامنه 

count       1460
unique         2
top       AllPub
freq        1459
Name: Utilities, dtype: object
----------------------------------------------------------------------------
1) ویژگی ها 
LotConfig: فراوانی پیکربندی
    
برچسب هایش: 

       Inside	Inside lot
       Corner	Corner lot
       CulDSac	Cul-de-sac
       FR2	Frontage on 2 sides of property
       FR3	Frontage on 3 sides of property

نوع: 

    Nominal

2)  گسسته یا پیوسته؟ 

    گسسته

3) دامنه 

count       1460
unique         5
top       Inside
freq        1052
Name: LotConfig, dtype: object
----------------------------------------------------------------------------
1) ویژگی ها 
LandSlope: شیب ملک
    
برچسب هایش: 

       Gtl	Gentle slope
       Mod	Moderate Slope	
       Sev	Severe Slope

نوع: 

    Nominal

2)  گسسته یا پیوسته؟ 

    گسسته

3) دامنه 

count     1460
unique       3
top        Gtl
freq      1382
Name: LandSlope, dtype: object
----------------------------------------------------------------------------
1) ویژگی ها 
Neighborhood: مکان های فیزیکی با یک محدودیت خاص
    
برچسب هایش: 

       Blmngtn	Bloomington Heights
       Blueste	Bluestem
       BrDale	Briardale
       BrkSide	Brookside
       ClearCr	Clear Creek
       CollgCr	College Creek
       Crawfor	Crawford
       Edwards	Edwards
       Gilbert	Gilbert
       IDOTRR	Iowa DOT and Rail Road
       MeadowV	Meadow Village
       Mitchel	Mitchell
       Names	North Ames
       NoRidge	Northridge
       NPkVill	Northpark Villa
       NridgHt	Northridge Heights
       NWAmes	Northwest Ames
       OldTown	Old Town
       SWISU	South & West of Iowa State University
       Sawyer	Sawyer
       SawyerW	Sawyer West
       Somerst	Somerset
       StoneBr	Stone Brook
       Timber	Timberland
       Veenker	Veenker

نوع: 

    Nominal

2)  گسسته یا پیوسته؟ 

    گسسته

3) دامنه 

count      1460
unique       25
top       NAmes
freq        225
Name: Neighborhood, dtype: object
----------------------------------------------------------------------------
1) ویژگی ها 
Condition1: نزدیکی به شرایط مختلف
برچسب هایش: 

       Artery	Adjacent to arterial street
       Feedr	Adjacent to feeder street	
       Norm	Normal	
       RRNn	Within 200' of North-South Railroad
       RRAn	Adjacent to North-South Railroad
       PosN	Near positive off-site feature--park, greenbelt, etc.
       PosA	Adjacent to postive off-site feature
       RRNe	Within 200' of East-West Railroad
       RRAe	Adjacent to East-West Railroad

نوع: 

    Nominal

2)  گسسته یا پیوسته؟ 

    گسسته

3) دامنه 

count     1460
unique       9
top       Norm
freq      1260
Name: Condition1, dtype: object
----------------------------------------------------------------------------
1) ویژگی ها 
Condition2:نزدیکی به شرایط مختلف (در صورت وجود بیش از یک مورد)
    
برچسب هایش: 

       Artery	Adjacent to arterial street
       Feedr	Adjacent to feeder street	
       Norm	Normal	
       RRNn	Within 200' of North-South Railroad
       RRAn	Adjacent to North-South Railroad
       PosN	Near positive off-site feature--park, greenbelt, etc.
       PosA	Adjacent to postive off-site feature
       RRNe	Within 200' of East-West Railroad
       RRAe	Adjacent to East-West Railroad

نوع: 

    Nominal

2)  گسسته یا پیوسته؟ 

    گسسته

3) دامنه 

count     1460
unique       8
top       Norm
freq      1445
Name: Condition2, dtype: object
----------------------------------------------------------------------------
1) ویژگی ها 
BldgType: نوع مسکن
    
برچسب هایش: 

       1Fam	Single-family Detached	
       2FmCon	Two-family Conversion; originally built as one-family dwelling
       Duplx	Duplex
       TwnhsE	Townhouse End Unit
       TwnhsI	Townhouse Inside Unit

نوع: 

    Nominal

2)  گسسته یا پیوسته؟ 

    گسسته

3) دامنه 

count     1460
unique       5
top       1Fam
freq      1220
Name: BldgType, dtype: object
----------------------------------------------------------------------------
1) ویژگی ها 
HouseStyle: سبک سکونت
    
برچسب هایش: 

       1Story	One story
       1.5Fin	One and one-half story: 2nd level finished
       1.5Unf	One and one-half story: 2nd level unfinished
       2Story	Two story
       2.5Fin	Two and one-half story: 2nd level finished
       2.5Unf	Two and one-half story: 2nd level unfinished
       SFoyer	Split Foyer
       SLvl	Split Level

نوع: 

    Nominal

2)  گسسته یا پیوسته؟ 

    گسسته

3) دامنه 

count       1460
unique         8
top       1Story
freq         726
Name: HouseStyle, dtype: object
----------------------------------------------------------------------------
1) ویژگی ها 
OverallQual: متریال کلی و پایان خانه را رتبه بندی می کند
    
برچسب هایش: 

       10	Very Excellent
       9	Excellent
       8	Very Good
       7	Good
       6	Above Average
       5	Average
       4	Below Average
       3	Fair
       2	Poor
       1	Very Poor

نوع: 

    Ordered

2)  گسسته یا پیوسته؟ 

    گسسته

3) دامنه 

count    1460.000000
mean        6.099315
std         1.382997

min         1.000000
max        10.000000

Name: OverallQual, dtype: float64
----------------------------------------------------------------------------
1) ویژگی ها 
OverallCond: وضعیت کلی خانه را ارزیابی می کند
    
برچسب هایش: 

       10	Very Excellent
       9	Excellent
       8	Very Good
       7	Good
       6	Above Average	
       5	Average
       4	Below Average	
       3	Fair
       2	Poor
       1	Very Poor

نوع: 

    Ordered

2)  گسسته یا پیوسته؟ 

    گسسته

3) دامنه 

count    1460.000000
mean        5.575342
std         1.112799

min         1.000000
max         9.000000

Name: OverallCond, dtype: float64
----------------------------------------------------------------------------
1) ویژگی ها 
YearBuilt: تاریخ ساخت اصلی
    
برچسب هایش: 
 
 -----

نوع: 

    Numeric

2)  گسسته یا پیوسته؟ 

    پیوسته

3) دامنه 

count    1460.000000
mean     1971.267808
std        30.202904

min      1872.000000
max      2010.000000

Name: YearBuilt, dtype: float64
----------------------------------------------------------------------------
1) ویژگی ها 
YearRemodAdd: اریخ بازسازی (همان تاریخ ساخت در صورت عدم بازسازی یا اضافه شدن)
    
برچسب هایش: 

 -----

نوع: 

    Numeric

2)  گسسته یا پیوسته؟ 

    پیوسته

3) دامنه 

count    1460.000000
mean     1984.865753
std        20.645407

min      1950.000000
max      2010.000000

Name: YearRemodAdd, dtype: float64
----------------------------------------------------------------------------
1) ویژگی ها 
RoofStyle: نوع سقف
    
برچسب هایش: 

       Flat	Flat
       Gable	Gable
       Gambrel	Gabrel (Barn)
       Hip	Hip
       Mansard	Mansard
       Shed	Shed

نوع: 

    Nominal

2)  گسسته یا پیوسته؟ 

    گسسته 

3) دامنه 

count      1460
unique        6
top       Gable
freq       1141
Name: RoofStyle, dtype: object
----------------------------------------------------------------------------
1) ویژگی ها 
RoofMatl: مواد سقف
    
برچسب هایش: 

       ClyTile	Clay or Tile
       CompShg	Standard (Composite) Shingle
       Membran	Membrane
       Metal	Metal
       Roll	Roll
       Tar&Grv	Gravel & Tar
       WdShake	Wood Shakes
       WdShngl	Wood Shingles

نوع: 

    Nominal

2)  گسسته یا پیوسته؟ 

    گسسته 

3) دامنه 

count        1460
unique          8
top       CompShg
freq         1434
Name: RoofMatl, dtype: object
----------------------------------------------------------------------------
1) ویژگی ها 
Exterior1st: پوشش بیرونی خانه
    
برچسب هایش: 

       AsbShng	Asbestos Shingles
       AsphShn	Asphalt Shingles
       BrkComm	Brick Common
       BrkFace	Brick Face
       CBlock	Cinder Block
       CemntBd	Cement Board
       HdBoard	Hard Board
       ImStucc	Imitation Stucco
       MetalSd	Metal Siding
       Other	Other
       Plywood	Plywood
       PreCast	PreCast	
       Stone	Stone
       Stucco	Stucco
       VinylSd	Vinyl Siding
       Wd Sdng	Wood Siding
       WdShing	Wood Shingles

نوع: 

    Nominal

2)  گسسته یا پیوسته؟ 

    گسسته 

3) دامنه 

count        1460
unique         15
top       VinylSd
freq          515
Name: Exterior1st, dtype: object
----------------------------------------------------------------------------
1) ویژگی ها 
Exterior2nd:  پوشش بیرونی خانه (اگر بیش از یک ماده باشد)
    
برچسب هایش: 

       AsbShng	Asbestos Shingles
       AsphShn	Asphalt Shingles
       BrkComm	Brick Common
       BrkFace	Brick Face
       CBlock	Cinder Block
       CemntBd	Cement Board
       HdBoard	Hard Board
       ImStucc	Imitation Stucco
       MetalSd	Metal Siding
       Other	Other
       Plywood	Plywood
       PreCast	PreCast
       Stone	Stone
       Stucco	Stucco
       VinylSd	Vinyl Siding
       Wd Sdng	Wood Siding
       WdShing	Wood Shingles

نوع: 

    Nominal

2)  گسسته یا پیوسته؟ 

    گسسته 

3) دامنه 

count        1460
unique         16
top       VinylSd
freq          504
Name: Exterior2nd, dtype: object
----------------------------------------------------------------------------
1) ویژگی ها 
MasVnrType: نوع روکش بنایی
    
برچسب هایش: 

       BrkCmn	Brick Common
       BrkFace	Brick Face
       CBlock	Cinder Block
       None	None
       Stone	Stone

نوع: 

    Nominal

2)  گسسته یا پیوسته؟ 

    گسسته

3) دامنه 

count     1452
unique       4
top       None
freq       864
Name: MasVnrType, dtype: object
----------------------------------------------------------------------------
1) ویژگی ها 
MasVnrArea: سطح روکش بنایی در متر مربع
    
برچسب هایش: 

 -----

نوع: 

    Numeric

2)  گسسته یا پیوسته؟ 

    پیوسته

3) دامنه 

count    1452.000000
mean      103.685262
std       181.066207

min         0.000000
max      1600.000000

Name: MasVnrArea, dtype: float64
----------------------------------------------------------------------------
1) ویژگی ها 
ExterQual: کیفیت مواد را در نمای بیرونی ارزیابی می کند
    
برچسب هایش: 

       Ex	Excellent
       Gd	Good
       TA	Average/Typical
       Fa	Fair
       Po	Poor

نوع: 

    Ordered

2)  گسسته یا پیوسته؟ 

    گسسته

3) دامنه 

count     1460
unique       4
top         TA
freq       906
Name: ExterQual, dtype: object
----------------------------------------------------------------------------
1) ویژگی ها 
ExterCond: وضعیت فعلی مواد را در نمای بیرونی ارزیابی می کند
    
برچسب هایش: 

       Ex	Excellent
       Gd	Good
       TA	Average/Typical
       Fa	Fair
       Po	Poor

نوع: 

    Ordered

2)  گسسته یا پیوسته؟ 

    گسسته

3) دامنه 

count     1460
unique       5
top         TA
freq      1282
Name: ExterCond, dtype: object
----------------------------------------------------------------------------
1) ویژگی ها 
Foundation: نوع فونداسیون
    
برچسب هایش: 

       BrkTil	Brick & Tile
       CBlock	Cinder Block
       PConc	Poured Contrete	
       Slab	Slab
       Stone	Stone
       Wood	Wood

نوع: 

    Nominal

2)  گسسته یا پیوسته؟ 

    گسسته 

3) دامنه 

count      1460
unique        6
top       PConc
freq        647
Name: Foundation, dtype: object
----------------------------------------------------------------------------
1) ویژگی ها 
BsmtQual: ارتفاع زیرزمین را ارزیابی می کند
    
برچسب هایش: 

       Ex	Excellent (100+ inches)	
       Gd	Good (90-99 inches)
       TA	Typical (80-89 inches)
       Fa	Fair (70-79 inches)
       Po	Poor (<70 inches
       NA	No Basement

نوع: 

    Ordered

2)  گسسته یا پیوسته؟ 

    گسسته

3) دامنه 

count     1423
unique       4
top         TA
freq       649
Name: BsmtQual, dtype: object
----------------------------------------------------------------------------
1) ویژگی ها 
BsmtCond: وضعیت عمومی زیرزمین را ارزیابی می کند        
    
برچسب هایش: 

       Ex	Excellent
       Gd	Good
       TA	Typical - slight dampness allowed
       Fa	Fair - dampness or some cracking or settling
       Po	Poor - Severe cracking, settling, or wetness
       NA	No Basement

نوع: 

    Ordered

2)  گسسته یا پیوسته؟ 

    گسسته

3) دامنه 

count     1423
unique       4
top         TA
freq      1311
Name: BsmtCond, dtype: object
----------------------------------------------------------------------------
1) ویژگی ها 
BsmtExposure: به دیوارهای پیاده یا سطح باغ اشاره دارد
    
برچسب هایش: 

       Gd	Good Exposure
       Av	Average Exposure (split levels or foyers typically score average or above)	
       Mn	Mimimum Exposure
       No	No Exposure
       NA	No Basement

نوع: 

    Nominal

2)  گسسته یا پیوسته؟ 

    گسسته

3) دامنه 

count     1422
unique       4
top         No
freq       953
Name: BsmtExposure, dtype: object
----------------------------------------------------------------------------
1) ویژگی ها 
BsmtFinType1: رتبه بندی مساحت تمام شده زیرزمین
    
برچسب هایش: 

       GLQ	Good Living Quarters
       ALQ	Average Living Quarters
       BLQ	Below Average Living Quarters	
       Rec	Average Rec Room
       LwQ	Low Quality
       Unf	Unfinshed
       NA	No Basement

نوع: 

    Ordered

2)  گسسته یا پیوسته؟ 

    گسسته

3) دامنه 

count     1423
unique       6
top        Unf
freq       430
Name: BsmtFinType1, dtype: object
----------------------------------------------------------------------------
1) ویژگی ها 
BsmtFinSF1: مساحت تمام شده نوع 1 در متر مربع
    
برچسب هایش: 

 -----

نوع: 

    Numeric

2)  گسسته یا پیوسته؟ 

    پیوسته

3) دامنه 

count    1460.000000
mean      443.639726
std       456.098091

min         0.000000
max      5644.000000

Name: BsmtFinSF1, dtype: float64
----------------------------------------------------------------------------
1) ویژگی ها 
BsmtFinType2: رتبه بندی مساحت تمام شده زیرزمین (در صورت چند نوع)
    
برچسب هایش: 

       GLQ	Good Living Quarters
       ALQ	Average Living Quarters
       BLQ	Below Average Living Quarters	
       Rec	Average Rec Room
       LwQ	Low Quality
       Unf	Unfinshed
       NA	No Basement

نوع: 

    Ordered

2)  گسسته یا پیوسته؟ 

    گسسته

3) دامنه 

count     1422
unique       6
top        Unf
freq      1256
Name: BsmtFinType2, dtype: object
----------------------------------------------------------------------------
1) ویژگی ها 
BsmtFinSF2: مساحت تمام شده نوع 2 در متر مربع
    
برچسب هایش: 

 -----

نوع: 

    Numeric

2)  گسسته یا پیوسته؟ 

    پیوسته

3) دامنه 

count    1460.000000
mean       46.549315
std       161.319273

min         0.000000
max      1474.000000

Name: BsmtFinSF2, dtype: float64
----------------------------------------------------------------------------
1) ویژگی ها 
BsmtUnfSF: متر مربع تمام نشده مساحت زیرزمین
    
برچسب هایش: 

 -----

نوع: 

    Numeric

2)  گسسته یا پیوسته؟ 

    پیوسته

3) دامنه 

count    1460.000000
mean      567.240411
std       441.866955

min         0.000000
max      2336.000000

Name: BsmtUnfSF, dtype: float64
----------------------------------------------------------------------------
1) ویژگی ها 
TotalBsmtSF: کل متر مربع مساحت زیرزمین
    
برچسب هایش: 

 -----

نوع: 

    Numeric

2)  گسسته یا پیوسته؟ 

    پیوسته

3) دامنه 

count    1460.000000
mean     1057.429452
std       438.705324

min         0.000000
max      6110.000000

Name: TotalBsmtSF, dtype: float64
----------------------------------------------------------------------------
1) ویژگی ها 
Heating: نوع گرمایش
    
برچسب هایش: 

       Floor	Floor Furnace
       GasA	Gas forced warm air furnace
       GasW	Gas hot water or steam heat
       Grav	Gravity furnace	
       OthW	Hot water or steam heat other than gas
       Wall	Wall furnace

نوع: 

    Nominal

2)  گسسته یا پیوسته؟ 

    گسسته

3) دامنه 

count     1460
unique       6
top       GasA
freq      1428
Name: Heating, dtype: object
----------------------------------------------------------------------------
1) ویژگی ها 
HeatingQC: کیفیت و وضعیت گرمایش
    
برچسب هایش: 

       Ex	Excellent
       Gd	Good
       TA	Average/Typical
       Fa	Fair
       Po	Poor

نوع: 

    Ordered

2)  گسسته یا پیوسته؟ 

    گسسته

3) دامنه 

count     1460
unique       5
top         Ex
freq       741
Name: HeatingQC, dtype: object
----------------------------------------------------------------------------
1) ویژگی ها 
CentralAir: تهویه مطبوع مرکزی
    
برچسب هایش: 

       N	No
       Y	Yes

نوع: 

    Binary

2)  گسسته یا پیوسته؟ 

    گسسته

3) دامنه 

count     1460
unique       2
top          Y
freq      1365
Name: CentralAir, dtype: object
----------------------------------------------------------------------------
1) ویژگی ها 
Electrical: سیستم الکتریکی
    
برچسب هایش: 

       SBrkr	Standard Circuit Breakers & Romex
       FuseA	Fuse Box over 60 AMP and all Romex wiring (Average)	
       FuseF	60 AMP Fuse Box and mostly Romex wiring (Fair)
       FuseP	60 AMP Fuse Box and mostly knob & tube wiring (poor)
       Mix	Mixed

نوع: 

    Nominal

2)  گسسته یا پیوسته؟ 

    گسسته

3) دامنه 

count      1459
unique        5
top       SBrkr
freq       1334
Name: Electrical, dtype: object
----------------------------------------------------------------------------
1) ویژگی ها 
1stFlrSF: طبقه اول متر مربع
    
برچسب هایش: 

 ------

نوع: 

    Numeric

2)  گسسته یا پیوسته؟ 

    پیوسته

3) دامنه 

count    1460.000000
mean     1162.626712
std       386.587738

min       334.000000
max      4692.000000

Name: 1stFlrSF, dtype: float64
----------------------------------------------------------------------------
1) ویژگی ها 
2ndFlrSF: طبقه دوم متر مربع
    
برچسب هایش: 

 ------

نوع: 

    Numeric

2)  گسسته یا پیوسته؟ 

    پیوسته

3) دامنه 

count    1460.000000
mean      346.992466
std       436.528436

min         0.000000
max      2065.000000

Name: 2ndFlrSF, dtype: float64
----------------------------------------------------------------------------
1) ویژگی ها 
LowQualFinSF: متر مربع تمام شده با کیفیت پایین (همه طبقات)
    
برچسب هایش: 

 ------

نوع: 

    Numeric

2)  گسسته یا پیوسته؟ 

    پیوسته

3) دامنه 

count    1460.000000
mean        5.844521
std        48.623081

min         0.000000
max       572.000000

Name: LowQualFinSF, dtype: float64
----------------------------------------------------------------------------
1) ویژگی ها 
GrLivArea: سطح بالای (زمین) منطقه نشیمن متر مربع
    
برچسب هایش: 

 ------

نوع: 

    Numeric

2)  گسسته یا پیوسته؟ 

    پیوسته

3) دامنه 

count    1460.000000
mean     1515.463699
std       525.480383

min       334.000000
max      5642.000000

Name: GrLivArea, dtype: float64
----------------------------------------------------------------------------
1) ویژگی ها 
BsmtFullBath: حمام های کامل زیرزمین
    
برچسب هایش: 

 ------

نوع: 

    Numeric

2)  گسسته یا پیوسته؟ 

    گسسته

3) دامنه 

count    1460.000000
mean        0.425342
std         0.518911

min         0.000000
max         3.000000

Name: BsmtFullBath, dtype: float64
----------------------------------------------------------------------------
1) ویژگی ها 
BsmtHalfBath: نیم حمام زیرزمین
    
برچسب هایش: 

 ------

نوع: 

    Numeric

2)  گسسته یا پیوسته؟ 

    گسسته

3) دامنه 

count    1460.000000
mean        0.057534
std         0.238753

min         0.000000
max         2.000000

Name: BsmtHalfBath, dtype: float64
----------------------------------------------------------------------------
1) ویژگی ها 
FullBath: حمام کامل بالاتر از درجه
    
برچسب هایش: 

 ------

نوع: 

    Numeric

2)  گسسته یا پیوسته؟ 

    گسسته

3) دامنه 

count    1460.000000
mean        1.565068
std         0.550916

min         0.000000
max         3.000000

Name: FullBath, dtype: float64
----------------------------------------------------------------------------
1) ویژگی ها 
HalfBath: نیم حمام بالاتر از درجه
    
برچسب هایش: 

 ------

نوع: 

    Numeric

2)  گسسته یا پیوسته؟ 

    گسسته

3) دامنه 

count    1460.000000
mean        0.382877
std         0.502885

min         0.000000
max         2.000000

Name: HalfBath, dtype: float64
----------------------------------------------------------------------------
1) ویژگی ها 
Bedroom: اتاق خواب های بالاتر از درجه (شامل اتاق خواب های زیرزمین نمی شود)
    
برچسب هایش: 

 ------

نوع: 

    Numeric

2)  گسسته یا پیوسته؟ 

    گسسته

3) دامنه 

count    1460.000000
mean        2.866438
std         0.815778

min         0.000000
max         8.000000

Name: BedroomAbvGr, dtype: float64
----------------------------------------------------------------------------
1) ویژگی ها 
Kitchen: آشپزخانه های بالاتر از درجه
    
برچسب هایش: 

 ------

نوع: 

    Numeric

2)  گسسته یا پیوسته؟ 

    گسسته

3) دامنه 

count    1460.000000
mean        1.046575
std         0.220338

min         0.000000
max         3.000000

Name: KitchenAbvGr, dtype: float64
----------------------------------------------------------------------------
1) ویژگی ها 
KitchenQual: کیفیت آشپزخانه
    
برچسب هایش: 

       Ex	Excellent
       Gd	Good
       TA	Typical/Average
       Fa	Fair
       Po	Poor

نوع: 

    Ordered

2)  گسسته یا پیوسته؟ 

    گسسته

3) دامنه 

count     1460
unique       4
top         TA
freq       735
Name: KitchenQual, dtype: object
----------------------------------------------------------------------------
1) ویژگی ها 
TotRmsAbvGrd: مجموع اتاق های بالاتر از درجه (شامل حمام نمی شود)
    
برچسب هایش: 

 -----

نوع: 

    Numeric

2)  گسسته یا پیوسته؟ 

    گسسته 

3) دامنه 

count    1460.000000
mean        6.517808
std         1.625393

min         2.000000
max        14.000000

Name: TotRmsAbvGrd, dtype: float64
----------------------------------------------------------------------------
1) ویژگی ها 
Functional: عملکرد خانه (معمولی را فرض کنید مگر اینکه کسرها ضمانت داشته باشند)
    
برچسب هایش: 

       Typ	Typical Functionality
       Min1	Minor Deductions 1
       Min2	Minor Deductions 2
       Mod	Moderate Deductions
       Maj1	Major Deductions 1
       Maj2	Major Deductions 2
       Sev	Severely Damaged
       Sal	Salvage only

نوع: 

    Nominal

2)  گسسته یا پیوسته؟ 

    گسسته

3) دامنه 

count     1460
unique       7
top        Typ
freq      1360
Name: Functional, dtype: object
----------------------------------------------------------------------------
1) ویژگی ها 
Fireplaces: تعداد شومینه
    
برچسب هایش: 

 -----

نوع: 

    Numeric

2)  گسسته یا پیوسته؟ 

    گسسته 

3) دامنه 

count    1460.000000
mean        0.613014
std         0.644666

min         0.000000
max         3.000000

Name: Fireplaces, dtype: float64
----------------------------------------------------------------------------
1) ویژگی ها 
FireplaceQu: کیفیت شومینه
    
برچسب هایش: 

       Ex	Excellent - Exceptional Masonry Fireplace
       Gd	Good - Masonry Fireplace in main level
       TA	Average - Prefabricated Fireplace in main living area or Masonry Fireplace in basement
       Fa	Fair - Prefabricated Fireplace in basement
       Po	Poor - Ben Franklin Stove
       NA	No Fireplace

نوع: 

    Ordered

2)  گسسته یا پیوسته؟ 

    گسسته

3) دامنه 

count     770
unique      5
top        Gd
freq      380
Name: FireplaceQu, dtype: object
----------------------------------------------------------------------------
1) ویژگی ها 
GarageType: محل گاراژ
    
برچسب هایش: 

       2Types	More than one type of garage
       Attchd	Attached to home
       Basment	Basement Garage
       BuiltIn	Built-In (Garage part of house - typically has room above garage)
       CarPort	Car Port
       Detchd	Detached from home
       NA	No Garage

نوع: 

    Nominal

2)  گسسته یا پیوسته؟ 

    گسسته

3) دامنه 

count       1379
unique         6
top       Attchd
freq         870
Name: GarageType, dtype: object
----------------------------------------------------------------------------
1) ویژگی ها 
GarageYrBlt: سال گاراژ ساخته شد
    
برچسب هایش: 

 -----

نوع: 

    Numeric

2)  گسسته یا پیوسته؟ 

    پیوسته

3) دامنه 

count    1379.000000
mean     1978.506164
std        24.689725

min      1900.000000
max      2010.000000

Name: GarageYrBlt, dtype: float64
----------------------------------------------------------------------------
1) ویژگی ها 
GarageFinish: نمای داخلی گاراژ
    
برچسب هایش: 

       Fin	Finished
       RFn	Rough Finished	
       Unf	Unfinished
       NA	No Garage

نوع: 

    Nominal

2)  گسسته یا پیوسته؟ 

    گسسته

3) دامنه 

count     1379
unique       3
top        Unf
freq       605
Name: GarageFinish, dtype: object
----------------------------------------------------------------------------
1) ویژگی ها 
GarageCars: اندازه گاراژ در ظرفیت ماشین
    
برچسب هایش: 

 -----

نوع: 

    Numeric

2)  گسسته یا پیوسته؟ 

     پیوسته

3) دامنه 

count    1460.000000
mean        1.767123
std         0.747315

min         0.000000
max         4.000000

Name: GarageCars, dtype: float64
----------------------------------------------------------------------------
1) ویژگی ها 
GarageArea: اندازه گاراژ در متر مربع
    
برچسب هایش: 

 -----

نوع: 

    Numeric

2)  گسسته یا پیوسته؟ 

     پیوسته

3) دامنه 

count    1460.000000
mean      472.980137
std       213.804841

min         0.000000
max      1418.000000

Name: GarageArea, dtype: float64
----------------------------------------------------------------------------
1) ویژگی ها 
GarageQual: کیفیت گاراژ
    
برچسب هایش: 

       Ex	Excellent
       Gd	Good
       TA	Typical/Average
       Fa	Fair
       Po	Poor
       NA	No Garage

نوع: 

    Ordered

2)  گسسته یا پیوسته؟ 

    گسسته

3) دامنه 

count     1379
unique       5
top         TA
freq      1311
Name: GarageQual, dtype: object
----------------------------------------------------------------------------
1) ویژگی ها 
GarageCond: وضعیت گاراژ
    
برچسب هایش: 

       Ex	Excellent
       Gd	Good
       TA	Typical/Average
       Fa	Fair
       Po	Poor
       NA	No Garage

نوع: 


    Ordered

2)  گسسته یا پیوسته؟ 

    گسسته

3) دامنه 

count     1379
unique       5
top         TA
freq      1326
Name: GarageCond, dtype: object
----------------------------------------------------------------------------
1) ویژگی ها 
PavedDrive: راهروی آسفالت شده
    
برچسب هایش: 

       Y	Paved 
       P	Partial Pavement
       N	Dirt/Gravel

نوع: 

    Nominal

2)  گسسته یا پیوسته؟ 

    گسسته

3) دامنه 

count     1460
unique       3
top          Y
freq      1340
Name: PavedDrive, dtype: object
----------------------------------------------------------------------------
1) ویژگی ها 
WoodDeckSF: مساحت عرشه چوبی در متر مربع
    
برچسب هایش: 

 -----

نوع: 

    Numeric

2)  گسسته یا پیوسته؟ 

    پیوسته

3) دامنه 

count    1460.000000
mean       94.244521
std       125.338794

min         0.000000
max       857.000000

Name: WoodDeckSF, dtype: float64
----------------------------------------------------------------------------
1) ویژگی ها 
OpenPorchSF: مساحت ایوان باز در متر مربع
    
برچسب هایش: 

 -----

نوع: 

    Numeric

2)  گسسته یا پیوسته؟ 

    پیوسته

3) دامنه 

count    1460.000000
mean       46.660274
std        66.256028

min         0.000000
max       547.000000

Name: OpenPorchSF, dtype: float64
----------------------------------------------------------------------------
1) ویژگی ها 
EnclosedPorch: محوطه ایوان محصور در متر مربع
    
برچسب هایش: 

 -----

نوع: 

    Numeric

2)  گسسته یا پیوسته؟ 

    پیوسته

3) دامنه 

count    1460.000000
mean       21.954110
std        61.119149

min         0.000000
max       552.000000

Name: EnclosedPorch, dtype: float64
----------------------------------------------------------------------------
1) ویژگی ها 
3SsnPorch: مساحت ایوان سه فصل به متر مربع
    
برچسب هایش: 

 -----

نوع: 

    Numeric

2)  گسسته یا پیوسته؟ 

    پیوسته

3) دامنه 

count    1460.000000
mean        3.409589
std        29.317331

min         0.000000
max       508.000000

Name: 3SsnPorch, dtype: float64
----------------------------------------------------------------------------
1) ویژگی ها 
ScreenPorch: مساحت ایوان پرده در متر مربع
    
برچسب هایش: 

 -----

نوع: 

    Numeric

2)  گسسته یا پیوسته؟ 

    پیوسته

3) دامنه 

count    1460.000000
mean       15.060959
std        55.757415

min         0.000000
max       480.000000

Name: ScreenPorch, dtype: float64
----------------------------------------------------------------------------
1) ویژگی ها 
PoolArea: مساحت استخر در متر مربع
    
برچسب هایش: 
 -----

نوع: 

    Numeric

2)  گسسته یا پیوسته؟ 

    پیوسته

3) دامنه 

count    1460.000000
mean        2.758904
std        40.177307

min         0.000000
max       738.000000

Name: PoolArea, dtype: float64
----------------------------------------------------------------------------
1) ویژگی ها 
PoolQC: کیفیت استخر
    
برچسب هایش: 

       Ex	Excellent
       Gd	Good
       TA	Average/Typical
       Fa	Fair
       NA	No Pool

نوع: 

    Ordered

2)  گسسته یا پیوسته؟ 

    گسسته

3) دامنه 

count      7
unique     3
top       Gd
freq       3
Name: PoolQC, dtype: object
----------------------------------------------------------------------------
1) ویژگی ها 
Fence: کیفیت نرده
    
برچسب هایش: 

       GdPrv	Good Privacy
       MnPrv	Minimum Privacy
       GdWo	Good Wood
       MnWw	Minimum Wood/Wire
       NA	No Fence

نوع: 

    Nominal

2)  گسسته یا پیوسته؟ 

    گسسته

3) دامنه 

count       281
unique        4
top       MnPrv
freq        157
Name: Fence, dtype: object
----------------------------------------------------------------------------
1) ویژگی ها 
MiscFeature: ویژگی متفرقه که در دسته های دیگر پوشش داده نمی شود
    
برچسب هایش: 

       Elev	Elevator
       Gar2	2nd Garage (if not described in garage section)
       Othr	Other
       Shed	Shed (over 100 SF)
       TenC	Tennis Court
       NA	None

نوع: 

    Nominal

2)  گسسته یا پیوسته؟ 

    گسسته

3) دامنه 

count       54
unique       4
top       Shed
freq        49
Name: MiscFeature, dtype: object
----------------------------------------------------------------------------
1) ویژگی ها 
MiscVal: ارزش ویژگی متفرقه به دلار
    
برچسب هایش: 

 ----

نوع: 

    Numeric

2)  گسسته یا پیوسته؟ 

    پیوسته

3) دامنه 

count     1460.000000
mean        43.489041
std        496.123024

min          0.000000
max      15500.000000

Name: MiscVal, dtype: float64
----------------------------------------------------------------------------
1) ویژگی ها 
MoSold: ماه فروخته شده
    
برچسب هایش: 

 ----

نوع: 

    Numeric

2)  گسسته یا پیوسته؟ 

    پیوسته

3) دامنه 

count    1460.000000
mean        6.321918
std         2.703626

min         1.000000
max        12.000000

Name: MoSold, dtype: float64
----------------------------------------------------------------------------
1) ویژگی ها 
YrSold: سال فروخته شده
    
برچسب هایش: 

 ----

نوع: 

    Numeric

2)  گسسته یا پیوسته؟ 

    پیوسته

3) دامنه 

count    1460.000000
mean     2007.815753
std         1.328095

min      2006.000000
max      2010.000000

Name: YrSold, dtype: float64
----------------------------------------------------------------------------
1) ویژگی ها 
SaleType: نوع فروش
    
برچسب هایش: 

       WD 	Warranty Deed - Conventional
       CWD	Warranty Deed - Cash
       VWD	Warranty Deed - VA Loan
       New	Home just constructed and sold
       COD	Court Officer Deed/Estate
       Con	Contract 15% Down payment regular terms
       ConLw	Contract Low Down payment and low interest
       ConLI	Contract Low Interest
       ConLD	Contract Low Down
       Oth	Other

نوع: 

    Nominal

2)  گسسته یا پیوسته؟ 

    گسسته

3) دامنه 

count     1460
unique       9
top         WD
freq      1267
Name: SaleType, dtype: object
----------------------------------------------------------------------------
1) ویژگی ها 
SaleCondition: شرایط فروش
    
برچسب هایش: 

 -----

نوع: 

    Nominal 

2)  گسسته یا پیوسته؟ 

    گسسته

3) دامنه 

count       1460
unique         6
top       Normal
freq        1198
Name: SaleCondition, dtype: object
----------------------------------------------------------------------------
1) ویژگی ها 
SalePrice: قیمت فروش

برچسب هایش: 

 -----

نوع: 

    Numeric

2)  گسسته یا پیوسته؟ 

    پیوسته


3) دامنه 

count      1460.000000
mean     180921.195890
std       79442.502883
min       34900.000000
25%      129975.000000
50%      163000.000000
75%      214000.000000
max      755000.000000
Name: SalePrice, dtype: float64
----------------------------------------------------------------------------

# %% [markdown]
# 4) برچسب داده
#
# "SalePrice"
